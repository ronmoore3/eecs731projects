# %%
## Pair Plot Code

# import pandas dataframe
import pandas as pd

# import pyplot from matplotlib
import matplotlib.pyplot as plt

# import seaborn library
import warnings # ignore useless seaborn warnings
warnings.filterwarnings("ignore")
import seaborn as sns

sns.set(style="white", color_codes=True)

# load Shakespeare dataset
# get rid of filter out delimiters (commas) in data
shake = pd.read_csv('C:\\Users\\Ronald\\Documents\\EECS 731\\Homework2\\Shakespeare_data.csv', nrows=5000, sep=',')

# forward fill and backward fill any missing values (blank fields)
shake = shake.fillna(method='ffill').fillna(method='bfill')
shake.head()
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               1.0        1.1.1  KING HENRY IV
# 1         2  Henry IV               1.0        1.1.1  KING HENRY IV
# 2         3  Henry IV               1.0        1.1.1  KING HENRY IV
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %%
# see how many players are in the dataset and how many instances of the player
shake["Player"].value_counts()
# Out:
# FALSTAFF              654
# HOTSPUR               583
# PRINCE HENRY          582
# KING HENRY IV         363
# TALBOT                292
# EARL OF WORCESTER     192
# JOAN LA PUCELLE       174
# MORTIMER              162
# GLOUCESTER            161
# CHARLES               114
# Messenger             101
# PLANTAGENET           100
# VERNON                 91
# POINS                  88
# BEDFORD                83
# GLENDOWER              82
# OF WINCHESTER          71
# KING HENRY VI          67
# LADY PERCY             61
# WARWICK                61
# EARL OF DOUGLAS        52
# SOMERSET               52
# OF AUVERGNE            50
# Hostess                49
# GADSHILL               48
# SIR WALTER BLUNT       45
# WESTMORELAND           44
# EXETER                 43
# BURGUNDY               40
# ARCHBISHOP OF YORK     38
#                      ...
# BASSET                 10
# Captain                10
# Sheriff                 9
# LANCASTER               9
# ...

# %%
#Use factor plots to plot different features against each other
#Could only get this to work with two columns - need to seek a transformation (label encoding or one hot encoding)
sns.factorplot(x='Player', y='PlayerLinenumber', hue='Player', data=shake)

# %%
# need to encode Play, PlayerLinenumber, ActSceneLine, Player, and PlayerLine to encoding
shake_enc = shake.copy()

from sklearn.preprocessing import LabelEncoder

lb_enc = LabelEncoder()
shake_enc['Play_Code'] = lb_enc.fit_transform(shake['Play'])
shake_enc['ActSceneLine_Code'] = lb_enc.fit_transform(shake['ActSceneLine'])
shake_enc['PlayerLinenumber_Code'] = lb_enc.fit_transform(shake['PlayerLinenumber'])
shake_enc['PlayerLine_Code'] = lb_enc.fit_transform(shake['PlayerLine'])

# remove values from non-encoded values from dataframe
shake_enc.drop(['Dataline','Play','ActSceneLine', 'PlayerLinenumber','PlayerLine'], axis=1, inplace=True)
shake_enc.head() #Results in appending a new column to df
# Out:
#           Player  Play_Code  ActSceneLine_Code  PlayerLinenumber_Code  \
# 0  KING HENRY IV          0                  0                      0
# 1  KING HENRY IV          0                  0                      0
# 2  KING HENRY IV          0                  0                      0
# 3  KING HENRY IV          0                  0                      0
# 4  KING HENRY IV          0                 93                      0
#
#    PlayerLine_Code
# 0              105
# 1             2678
# 2             1110
# 3             2843
# 4             1228

# %%
# add a pair plot to see distribution of players
sns.pairplot(shake_enc, hue="Player")

# %%
# Naive Bayes Classifier Plot

# %%
from sklearn.naive_bayes import GaussianNB
X = shake_enc['Player_Code', 'ActSceneLine_Code']
Y = shake_enc['Play_Code']
clf = GaussianNB()
clf.fit(X, Y)

# %%
# Linear SVM classifier 
print(shake_enc.columns[1])
# Out:
# ActSceneLine_Code

# %%
from sklearn import svm
X = shake_enc[['ActSceneLine_Code','PlayerLine_Code']].as_matrix()
y = shake_enc['Player_Code']

model = svm.SVC(kernel='linear')
model.fit(X,y)

# %%
# plot model
w = model.coef[0]
a = -w[0] / w[1]
xx = np.linsspace(5,30)
yy = a * xx - (model.intercept_-[0]) /w[1]

b = model.support_vectors[0]
yy_down = a * xx + (b[1] - a * b[0])
b = model.support_vectors[-1]
yy_up = a * xx + (b[1] - a * b[0])
